# %% [markdown]
# # Deals Part 2: The Power of SQL `SELECT`s

# %% [markdown]
# *This notebook uses SQL select statements to learn about mergers and acquisitions in the 1990s. No, actually it's just all about SELECT statements.*

# %% [markdown]
# ## Library Imports & Database Connection
# Some version of the following will need to appear near the top of every notebook in this course. It imports the necessary software libraries and connects to a database

# %%
# All query results are returned as Pandas DataFrames 
import pandas as pd

# Needed for %sql Magic
# %load_ext sql

# use %sql magic to connect to the deals database
# %sql mysql+pymysql://dealsuser:deals@localhost/deals
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# 'Connected: dealsuser@deals'

# %% [markdown]
# Let's review, line by line:
# - The code above is actually Python, which is what Jupyter prefers to use natively.
# - The lines that start with `#` are comments with English text explaining what the line below is about.
# - The `import` line allows us to use the pandas library that is all the rage at data science parties. pandas -- note that the p is is never capitalized -- provides data structures that emulate database tables. We won't make use of it here but it may be useful in later assignments.
# - The `%load_ext` statement extends Jupyter to allow SQL statements instead of Python. Any statement that starts with %sql or %%sql is run as SQL instead of Python. For details of how this works, RTFM at the [ipython-sql](https://github.com/catherinedevlin/ipython-sql) repo on GitHub.
# - The last line uses `%sql` to connect to an online MySQL database. The pseudo-URL at the end (complete with `://` in the middle) tells Jupyter
#     i) how to connect (i.e., using the pymysql bridge),
#     ii) what kind of database server is on the other end of the connection (i.e., mysql),
#     iii) who is connecting (i.e., login with user `dealsuser` and password `deals`), and
#     iv) where to connect to (i.e., a databse called `deals` hosted on the local [same] computer as Jupyter).

# %% [markdown]
# ## A Brief Warmup
# To make sure that everything is working correctly, let's try a basic `SELECT` query. Copy the following into the code cell below.
#
# ```SQL
# %%sql
# /* Indicate that we are using the deals database */
# USE deals;
# /* Execute a test query  */
# SELECT *
# FROM Companies
# WHERE CompanyName like "%Inc."
# ```
# A few notes:
# - `%%sql` magic allows us to split SQL statements onto multiple lines.
# - `US`E indicates what database to use, which is useful when there are multiple database connections (e.g., when copying data from one database to another).
# - SQL comments use `/*  */` format.
# - The `SELECT` statement is broken out into multiple clauses, each with a different purpose. The last clause (`WHERE CompanyName like "%Inc."`) restricts the listing to only companies with "Inc." at the end of their names.
# - The table names are case sensitive! If we were to use `COMPANIES` instead of `Companies` then the query breaks. Try it yourself! (Why the nonstandard name? When this database was first created in 1998, it was distributed as an MS Access database, which always followed CamelCase for table names.)

# %%
# %%sql
# USE deals;
# SELECT *
# FROM Companies
# WHERE CompanyName like "%Inc.";
# Out:
#  * mysql+pymysql://dealsuser:***@localhost/deals
# 0 rows affected.
# 111 rows affected.
# [(2, 'Abitibi-Price Inc.'),
#  (5, 'AirTouch Communications, Inc.'),
#  (6, 'Alex. Brown Inc.'),
#  (7, 'Allegheny Power System Inc.'),
#  (318, 'American Bankers Insurance Group Inc.'),
#  (319, 'American International Group Inc.'),
#  (11, 'American Medical Response, Inc.'),
#  (13, 'American Standard Companies, Inc.'),
#  (19, 'Apria Healthcare Group Inc.'),
#  (20, 'Ascend Communications, Inc.'),
#  (25, 'Barnett Banks, Inc.'),
#  (314, 'BDM International Inc.'),
#  (311, 'Beckman Instruments, Inc.'),
#  (31, 'Brooks Fiber Properties, Inc.'),
#  (33, 'Burlington Resources Inc.'),
#  (35, 'Calilber Systems Inc.'),
#  (37, 'Cardinal Health, Inc.'),
#  (303, 'Caterpillar Inc.'),
#  (41, 'Central Fidelity Banks Inc.'),
#  (42, 'Century Telephone Enterprises Inc.'),
#  (279, 'Ciba Specialty Chemicals Inc.'),
#  (50, 'Clear Channel Communications, Inc.'),
#  (52, 'Coca-Cola Enterprises Inc.'),
#  (64, 'CUC International Inc.'),
#  (68, 'Destec Energy, Inc.'),
#  (70, 'DowBrands Inc.'),
#  (71, 'DQE Inc.'),
#  (79, 'Evans Withycombe Residential Inc.'),
#  (81, 'Excel Communications, Inc.'),
#  (85, 'First Bank System, Inc.'),
#  (89, 'First USA, Inc.'),
#  (90, 'Fisher Scientific International Inc.'),
#  (91, 'Fleet Financial Group, Inc.'),
#  (93, 'Fox Kids Worldwide Inc.'),
#  (94, 'Fred Meyer Inc.'),
#  (96, 'GPU, Inc.'),
#  (97, 'GranCare Inc.'),
#  (99, 'Greenfield Industries, Inc.'),
#  (102, 'Healthsource, Inc.'),
#  (278, 'Hercules Inc.'),
#  (108, 'HFS Inc.'),
#  (109, 'Hicks, Muse, Tate & Furst Inc.'),
#  (112, 'Homeside, Inc.'),
#  (114, 'Household International Inc.'),
#  (115, 'HSN Inc.'),
#  (122, 'Integrated Health Services Inc.'),
#  (123, 'International Family Entertainment Inc.'),
#  (126, 'Investor Group led by Transworld Healthcare Inc.'),
#  (130, 'JP Foodservice Inc.'),
#  (131, 'Kennametal Inc.'),
#  (132, 'Keystone International Inc.'),
#  (138, 'Laidlaw Environmental Services, Inc.'),
#  (140, 'Laidlaw Inc.'),
#  (145, 'Living Centers of America Inc.'),
#  (150, 'Lucent Technologies Inc.'),
#  (151, "Mac Frugal's Bargains & Close-Outs Inc."),
#  (152, 'Mallinckrodt Inc.'),
#  (300, 'Mapco Inc.'),
#  (153, 'Marriott International, Inc.'),
#  (154, 'Marsh & McLennan Companies, Inc.'),
#  (155, 'McAfee Associates Inc.'),
#  (156, 'McClatchy Newspapers, Inc.'),
#  (159, 'MedPartners, Inc.'),
#  (162, 'MESA, Inc.'),
#  (163, 'Monterey Resources Inc.'),
#  (165, 'Morgan Stanley Group Inc.'),
#  (170, 'Nellcor Puritan Bennett Inc.'),
#  (317, 'Newcourt Credit Group Inc.'),
#  (282, 'Ocean Energy Inc.'),
#  (177, 'Outdoor Systems Inc.'),
#  (178, 'Overseas Shipholding Group, Inc.'),
#  (179, 'Pacific Telecom Inc.'),
#  (183, 'Patriot American Hospitality Inc.'),
#  (187, 'PhyCor Inc.'),
#  (194, 'Quality Food Centers Inc.'),
#  (197, 'Raycom Media, Inc.'),
#  (296, 'Renal Treatment Centers Inc.'),
#  (202, 'Revco D.S., Inc.'),
#  (204, 'Rohr Inc.'),
#  (205, 'Rollins Environmental Services, Inc.'),
#  (207, 'Rykoff Sexton Inc.'),
#  (208, 'S.C. Johnson & Son Inc.'),
#  (211, 'Salomon Inc.'),
#  (213, 'Scudder, Stevens & Clark Inc.'),
#  (217, 'SFX Broadcasting Inc.'),
#  (289, 'Showboat Inc.'),
#  (294, 'Simon DeBartolo Group Inc.'),
#  (280, 'Sonat Inc.'),
#  (226, 'Tambrands Inc.'),
#  (227, 'Tandem Computers Inc.'),
#  (228, 'Target Therapeutics, Inc.'),
#  (231, 'Telco Communications Group Inc.'),
#  (232, 'Tele-Communications, Inc.'),
#  (233, 'Tencor Instruments Inc.'),
#  (234, 'Texaco Inc.'),
#  (297, 'Total Renal Care Holdings Inc.'),
#  (315, 'TRW Inc.'),
#  (246, 'U.S. West, Inc.'),
#  (247, 'Union Pacific Resources Group Inc.'),
#  (248, 'United Waste Systems, Inc.'),
#  (249, 'Universal Outdoor Holdings Inc.'),
#  (250, 'Universal Studios, Inc.'),
#  (252, 'USA Waste Services Inc.'),
#  (255, 'Value Health, Inc.'),
#  (256, 'Vencor, Inc.'),
#  (257, 'Verifone, Inc.'),
#  (259, 'Vivra Inc.'),
#  (261, 'Wal-Mart Stores, Inc.'),
#  (262, 'Washington Mutual Inc.'),
#  (264, 'Western Resources, Inc.'),
#  (268, 'WorldCom, Inc.')]

# %% [markdown]
# ## Your First Bug
# Run the code below, which has two SQL statements in a row. It has a bug, as indicated by a cryptic error message:
# > (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'SELECT *\nFROM Companies\nORDER BY CompanyID' at line 7")
#
# What does `Error Code: 1064` mean? It's a syntax error. Can you spot the bug in the code? In this case it's pretty subtle: we are missing a semi-colon (`;`) at the end of each SELECT statement. Add the missing semi-colons and rerun. It should work now (though only the results of the second query will be shown; it's a Jupyter thing).

# %%
# %%sql
# /* Select companies whose names end with Inc. */
# SELECT *
# FROM Companies
# WHERE CompanyName like "%Inc.";
#
# /* Select companies sorted by CompanyName */
# SELECT *
# FROM Companies
# ORDER BY CompanyID
# LIMIT 10;
# Out:
#  * mysql+pymysql://dealsuser:***@localhost/deals
# 111 rows affected.
# 10 rows affected.
# [(1, '3Com Corporation'),
#  (2, 'Abitibi-Price Inc.'),
#  (3, 'ADT Limited'),
#  (4, 'Advanta Corp. Credit card unit'),
#  (5, 'AirTouch Communications, Inc.'),
#  (6, 'Alex. Brown Inc.'),
#  (7, 'Allegheny Power System Inc.'),
#  (8, 'Allied Irish Banks P.L.C.'),
#  (9, 'American Electric Power Co. Inc. and Public Service'),
#  (10, 'American General Corp.')]

# %% [markdown]
# ## Your First Join
# Now let's add another query, this time with data from two tables: `Deals` and `DealParts`.

# %%
# %%sql
# SELECT DealName,PartNumber,DollarValue
# FROM Deals, DealParts
# WHERE Deals.DealID = DealParts.DealID
# LIMIT 10;
# Out:
#  * mysql+pymysql://dealsuser:***@localhost/deals
# 10 rows affected.
# [('ADT Limited', 1, Decimal('5600.0000')),
#  ('Advanta Corp.', 1, Decimal('1300.0000')),
#  ('Alex. Brown Inc.', 1, Decimal('1700.0000')),
#  ('Allied Colloids Group PLC', 1, Decimal('1810.0000')),
#  ('American First Financial Insurance Group Inc.', 1, Decimal('2200.0000')),
#  ('American Medical Response, Inc.', 1, Decimal('1120.0000')),
#  ('American Radio Systems Corp.', 1, Decimal('2600.0000')),
#  ('American Standard Companies, Inc.', 1, Decimal('4000.0000')),
#  ('Amerisource Health Corp.', 1, Decimal('2322.0000')),
#  ('Amphenol Corp.', 1, Decimal('1500.0000'))]

# %% [markdown]
# Here we used the `WHERE` clause to indicate that the `DealID` on the `Deals` table has to match the `DealID` on the `DealParts` table. Believe it or not, that basic logic (that keys on one table have t match keys on anther table) is exactly 92% of the power of the Relational Database Model. We can now just end the course now. How about the final exam next week?

# %% [markdown]
# More seriously, while using the `WHERE` clause to match records from different tables works, it s not very efficient. Instead we will want to use a `JOIN .. USING` operator, which is optimized to work with millions of records without breaking a sweat. In this case we don't even need a WHERE clause!

# %%
# %%sql
# SELECT DealName,PartNumber,DollarValue
# FROM Deals
#      JOIN DealParts USING (DealID)
# LIMIT 10;
# Out:
#  * mysql+pymysql://dealsuser:***@localhost/deals
# 10 rows affected.
# [('ADT Limited', 1, Decimal('5600.0000')),
#  ('Advanta Corp.', 1, Decimal('1300.0000')),
#  ('Alex. Brown Inc.', 1, Decimal('1700.0000')),
#  ('Allied Colloids Group PLC', 1, Decimal('1810.0000')),
#  ('American First Financial Insurance Group Inc.', 1, Decimal('2200.0000')),
#  ('American Medical Response, Inc.', 1, Decimal('1120.0000')),
#  ('American Radio Systems Corp.', 1, Decimal('2600.0000')),
#  ('American Standard Companies, Inc.', 1, Decimal('4000.0000')),
#  ('Amerisource Health Corp.', 1, Decimal('2322.0000')),
#  ('Amphenol Corp.', 1, Decimal('1500.0000'))]

# %% [markdown]
# We can actually 'chain' table joins to link in data from as many tables as we want. We just have to specify what columns to use as keys! Each join in the chain creates a virtual table onto which we can join another table.

# %%
# %%sql
# SELECT DealName,LongCode as Role,CompanyName
# FROM Companies
#     JOIN Players USING (CompanyID)
#     JOIN RoleCodes USING (RoleCode)
#     JOIN Deals USING (DealID)
# ORDER BY DealName
# LIMIT 10;
# Out:
#  * mysql+pymysql://dealsuser:***@localhost/deals
# 10 rows affected.
# [('ADT Limited', 'Second Bidder', 'Tyco International Ltd.'),
#  ('ADT Limited', 'First Bidder', 'Western Resources, Inc.'),
#  ('ADT Limited', 'Target', 'ADT Limited'),
#  ('Advanta Corp.', 'Target', 'Advanta Corp. Credit card unit'),
#  ('Advanta Corp.', 'Acquiror', 'Fleet Financial Group, Inc.'),
#  ('Alex. Brown Inc.', 'Acquiror', 'Bankers Trust New York Corporation'),
#  ('Alex. Brown Inc.', 'Target', 'Alex. Brown Inc.'),
#  ('Allied Colloids Group PLC', 'First Bidder', 'Hercules Inc.'),
#  ('Allied Colloids Group PLC', 'Target', 'Allied Colloids Group'),
#  ('American First Financial Insurance Group Inc.', 'Acquiror', 'American International Group Inc.')]

# %% [markdown]
# Study the database schema below to see more opportunities to join tables. You will use this as a guide in the queries that follow.
#  ![Deals ERD](img/img2_7.png)

# %% [markdown]
# ## Challenge Queries: Now for the Fun Stuff
# Three queries are described below. In the code cell provided after each description, write a SQL query that best answers the question. Each query should answer the question completely, without us humans needing to do any sorting, counting, etc.
#
# Don't forget to start each query cell with `%%sql`.
#
# It's okay to collaborate with your classmates. Just be sure that you are typing out your own code.

# %% [markdown]
# ### Query 1: Lots of joins
# **For each deal, list every firm involved, what supporting role it played, and which company it supported.**
# You will need to output the following fields:
# - `DealName` from the `Deals` table
# - `Name` from the `Firms` table
# - `LongCode` from the `SupportCodes` table
# - `CompanyName` from the `Companies` table
#
# You will also need to use keys from the `Players` and `PlayerSupport` tables.

# %%
# %%sql
# SELECT DealName, Name AS FirmName, Longcode, CompanyName
# FROM Deals
#     JOIN Players USING (DealID)
#     JOIN Companies USING (CompanyID)
#     JOIN PlayerSupports USING (PlayerID)
#     JOIN Firms USING (FirmID)
#     JOIN SupportCodes USING (SupportCodeID)
#     LIMIT 20;
# Out:
#  * mysql+pymysql://dealsuser:***@localhost/deals
# 20 rows affected.
# [('Alex. Brown Inc.', 'BT Wolfensohn', 'Investment Adviser', 'Bankers Trust New York Corporation'),
#  ('Alex. Brown Inc.', 'Debevoise & Plimpton', 'Counsel', 'Bankers Trust New York Corporation'),
#  ('Alex. Brown Inc.', 'Kissel-Blake Inc.', 'Proxy Solicitor', 'Bankers Trust New York Corporation'),
#  ('Alex. Brown Inc.', 'Wachtell, Lipton, Rosen & Katz', 'Outside Counsel', 'Bankers Trust New York Corporation'),
#  ('American Medical Response, Inc.', 'Katten Muchin & Zavis', 'Outside Counsel', 'Laidlaw Inc.'),
#  ('American Medical Response, Inc.', 'Merrill Lynch & Co.', 'Investment Adviser', 'Laidlaw Inc.'),
#  ('American Medical Response, Inc.', 'Simpson Thacher & Bartlett', 'Counsel', 'Laidlaw Inc.'),
#  ('Amphenol Corp.', 'Donaldson, Lufkin & Jenrette Securities Corp.', 'Investment Adviser', 'Kohlberg Kravis Roberts & Co.'),
#  ('Amphenol Corp.', 'Kekst and Company', 'Public Relations Firm', 'Kohlberg Kravis Roberts & Co.'),
#  ('Amphenol Corp.', 'MacKenzie Partners, Inc.', 'Proxy Solicitor', 'Kohlberg Kravis Roberts & Co.'),
#  ('Amphenol Corp.', 'Simpson Thacher & Bartlett', 'Outside Counsel', 'Kohlberg Kravis Roberts & Co.'),
#  ('Berliner Kraft & Licht AG', 'Dresdner Kleinwort Benson', 'Investment Adviser', 'Inv. Group led by Southern Comp. and Viag AG'),
#  ('Berliner Kraft & Licht AG', 'Troutman Sanders', 'Outside Counsel', 'Inv. Group led by Southern Comp. and Viag AG'),
#  ('Cascade Communications Corp.', 'Deutsche Morgan Grenfell', 'Investment Adviser', 'Ascend Communications, Inc.'),
#  ('Cascade Communications Corp.', 'Gallagher PR', 'Public Relations Firm', 'Ascend Communications, Inc.'),
#  ('Cascade Communications Corp.', 'Gray Carey Ware & Friedenrich', 'Outside Counsel', 'Ascend Communications, Inc.'),
#  ('Cascade Communications Corp.', 'Richards, Layton & Finger', 'Outside Counsel', 'Ascend Communications, Inc.'),
#  ('Cascade Communications Corp.', 'Skinner & Co.', 'Proxy Solicitor', 'Ascend Communications, Inc.'),
#  ('Chancellor Broadcasting Comp.', 'Jaffoni & Collins Inc.', 'Public Relations Firm', 'Evergreen Media Corporation'),
#  ('Chancellor Broadcasting Comp.', 'Latham & Watkins', 'Outside Counsel', 'Evergreen Media Corporation')]

# %% [markdown]
# ### Query 2: Aggregation
# **List the DealID, total dollar value and number of parts for each deal.**
# Don't forget to use your database schema map when planning out your joins. Also, be sure to include a comment (above the code) indicating what the view is intended to do.

# %%
# %%sql
# SELECT DealID, SUM(DollarValue), COUNT(PartNumber)
# FROM DealParts
# GROUP BY DealID
# LIMIT 20;
# Out:
#  * mysql+pymysql://dealsuser:***@localhost/deals
# 20 rows affected.
# [(1, Decimal('5600.0000'), 1),
#  (2, Decimal('1700.0000'), 1),
#  (3, Decimal('1120.0000'), 1),
#  (4, Decimal('4000.0000'), 1),
#  (5, Decimal('1500.0000'), 1),
#  (6, Decimal('1600.0000'), 1),
#  (7, Decimal('1870.0000'), 1),
#  (8, Decimal('3700.0000'), 1),
#  (9, Decimal('1600.0000'), 1),
#  (10, Decimal('1200.0000'), 1),
#  (11, Decimal('1617.0000'), 1),
#  (12, Decimal('1360.0000'), 1),
#  (13, Decimal('1270.0000'), 1),
#  (14, Decimal('4210.0000'), 1),
#  (15, Decimal('1150.0000'), 1),
#  (16, Decimal('9700.0000'), 1),
#  (17, Decimal('1050.0000'), 1),
#  (18, Decimal('7000.0000'), 1),
#  (19, Decimal('3400.0000'), 1),
#  (20, Decimal('9500.0000'), 1)]

# %% [markdown]
# ### Query 3: Even More Aggregation
# **List the DealID, DealName, number of players, total dollar value, and number of parts for each deal.**
# Bonus: use a subquery to construct a comma-separated list of deal types for each deal. (Don't forget the explanatory comment.)

# %%
# %%sql
# SELECT DISTINCT DealID, DealName, Count(PlayerID), SUM(DollarValue), COUNT(PartNumber)
# FROM Deals
#     JOIN Players USING (DealID)
#     JOIN DealParts USING (DealID)
#     GROUP BY DealID
#     LIMIT 50
# ;
# Out:
#  * mysql+pymysql://dealsuser:***@localhost/deals
# 50 rows affected.
# [(1, 'ADT Limited', 3, Decimal('16800.0000'), 3),
#  (2, 'Alex. Brown Inc.', 2, Decimal('3400.0000'), 2),
#  (3, 'American Medical Response, Inc.', 2, Decimal('2240.0000'), 2),
#  (4, 'American Standard Companies, Inc.', 2, Decimal('8000.0000'), 2),
#  (5, 'Amphenol Corp.', 2, Decimal('3000.0000'), 2),
#  (6, 'Bankamerica Corp.', 1, Decimal('1600.0000'), 1),
#  (7, 'Berliner Kraft & Licht AG', 1, Decimal('1870.0000'), 1),
#  (8, 'Cascade Communications Corp.', 2, Decimal('7400.0000'), 2),
#  (9, 'Chancellor Broadcasting Comp.', 2, Decimal('3200.0000'), 2),
#  (10, 'Cifra S.A.', 2, Decimal('2400.0000'), 2),
#  (11, 'Coca Cola Bottling Co. of New York and Coca-Cola B', 2, Decimal('3234.0000'), 2),
#  (12, 'Dauphin Deposit Corp.', 2, Decimal('2720.0000'), 2),
#  (13, 'The Dow Chemical Company', 3, Decimal('3810.0000'), 3),
#  (14, 'DQE Inc.', 2, Decimal('8420.0000'), 2),
#  (15, 'Eller Media Corp.', 3, Decimal('3450.0000'), 3),
#  (16, 'The Energy Group PLC', 2, Decimal('19400.0000'), 2),
#  (17, 'First Financial Corp.', 2, Decimal('2100.0000'), 2),
#  (18, 'First USA, Inc.', 2, Decimal('14000.0000'), 2),
#  (19, 'Fort Howard Corp.', 2, Decimal('6800.0000'), 2),
#  (20, 'General Motors Corp.', 3, Decimal('28500.0000'), 3),
#  (21, 'Great Western Financial Corp.', 3, Decimal('19770.0000'), 3),
#  (22, 'Healthsource, Inc.', 2, Decimal('3400.0000'), 2),
#  (23, 'Hercules Inc. and Mallickrodt Inc', 2, Decimal('2200.0000'), 2),
#  (24, 'Heritage Media Corp.', 2, Decimal('2710.0000'), 2),
#  (25, 'HFS Inc.', 2, Decimal('21800.0000'), 2),
#  (26, 'Horizon/CMS Healthcare Corp.', 2, Decimal('3300.0000'), 2),
#  (27, 'International Family Entertainment Inc.', 5, Decimal('9500.0000'), 5),
#  (29, 'Johnson & Higgins', 2, Decimal('3600.0000'), 2),
#  (30, 'Keystone International Inc.', 3, Decimal('3600.0000'), 3),
#  (31, 'KU Energy Corporation', 2, Decimal('3000.0000'), 2),
#  (32, 'Laidlaw Inc.', 2, Decimal('2460.0000'), 2),
#  (33, 'Lincoln National Corporation', 2, Decimal('5640.0000'), 2),
#  (34, 'Living Centers of America Inc.', 3, Decimal('3000.0000'), 3),
#  (35, 'Minnesota Mining and Manufacturing Comp.', 2, Decimal('2000.0000'), 2),
#  (36, 'Morgan Stanley Group Inc.', 2, Decimal('21000.0000'), 2),
#  (37, 'Pacificorp', 2, Decimal('4446.0000'), 2),
#  (38, 'Parker & Parsley Petrolium Company', 2, Decimal('3600.0000'), 2),
#  (39, 'Read-Rite Corp.', 2, Decimal('3400.0000'), 2),
#  (40, 'Renaissance Hotel Group N.V.', 4, Decimal('4000.0000'), 4),
#  (41, 'Revco D.S., Inc.', 2, Decimal('7400.0000'), 2),
#  (42, 'Stone-Consolidated Corp.', 2, Decimal('3000.0000'), 2),
#  (43, 'Tambrands Inc.', 2, Decimal('4000.0000'), 2),
#  (44, 'Target Therapeutics, Inc.', 2, Decimal('2200.0000'), 2),
#  (45, 'Telco Communications Group Inc.', 3, Decimal('3240.0000'), 3),
#  (46, 'Tencor Instruments Inc.', 2, Decimal('2600.0000'), 2),
#  (47, 'Texas Instruments Inc.', 2, Decimal('5900.0000'), 2),
#  (48, 'Transamerica Corp.', 2, Decimal('2200.0000'), 2),
#  (49, 'The Unilever Group', 2, Decimal('16000.0000'), 2),
#  (50, 'United Waste Systems, Inc.', 2, Decimal('3000.0000'), 2),
#  (51, 'U.S. Bancorp', 2, Decimal('18000.0000'), 2)]

# %% [markdown]
# ### Query 4: A Surprisingly Tricky One
# **List TypeCode, number of deals, and total value of deals for each deal type.**
# Each firm should be listed, even if there are no deals for that firm.

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %%sql
# SELECT DISTINCT Name, COUNT(DealID)AS NumberOfDeals, TypeCode, SUM(DollarValue)
# FROM TypeCodes
# JOIN DealTypes USING (TypeCode)
# JOIN Deals USING (DealID)
# JOIN DealParts USING (DealID)
# JOIN Players USING (DealID)
# JOIN PlayerSupports USING (PlayerID)
# JOIN Firms USING (FirmID)
# GROUP BY Name, TypeCode
# ORDER BY Name;
# Out:
#  * mysql+pymysql://dealsuser:***@localhost/deals
# 467 rows affected.
# [('Akin Gump', 1, 'C/S', Decimal('1150.0000')),
#  ('Akin, Gump, Strauss, Hauer & Feld', 1, 'C/S', Decimal('1100.0000')),
#  ('Akin, Gump, Strauss, Hauer & Feld', 2, 'SS', Decimal('2950.0000')),
#  ('Alex. Brown & Sons Inc.', 1, 'C/S', Decimal('1150.0000')),
#  ('Alex. Brown & Sons Inc.', 1, 'SS', Decimal('1700.0000')),
#  ('Allen & Overy', 1, 'CM', Decimal('5300.0000')),
#  ('Allen & Overy', 1, 'TO', Decimal('2800.0000')),
#  ('Alston & Bird', 1, 'C/S', Decimal('18000.0000')),
#  ('Alston & Bird', 1, 'SS', Decimal('8180.0000')),
#  ('Andrews & Kurth', 3, 'C/S', Decimal('3140.0000')),
#  ('Andrews & Kurth', 3, 'SS', Decimal('3300.0000')),
#  ('Ashurst Morris Crisp', 1, 'TO', Decimal('2800.0000')),
#  ('BA Partners', 1, 'C/S', Decimal('1050.0000')),
#  ('Baker & Botts', 4, 'C/S', Decimal('9547.0000')),
#  ('Baker & Botts', 2, 'SS', Decimal('3000.0000')),
#  ('Baker & Botts', 1, 'TO', Decimal('6200.0000')),
#  ('Baker & MacKenzie', 1, 'C/S', Decimal('1200.0000')),
#  ('Banamex', 1, 'C/S', Decimal('1200.0000')),
#  ('Bankers Trust Corp.', 1, 'C/S', Decimal('1500.0000')),
#  ('Bartlit Beck Herman Palenchar & Scott', 1, 'C/S', Decimal('2350.0000')),
#  ('Bear, Stearns & Co., Inc.', 5, 'C/S', Decimal('15710.0000')),
#  ('Bear, Stearns & Co., Inc.', 2, 'PF', Decimal('19500.0000')),
#  ('Bear, Stearns & Co., Inc.', 4, 'SS', Decimal('27750.0000')),
#  ('Bear, Stearns & Co., Inc.', 5, 'TO', Decimal('28600.0000')),
#  ('Bennet Jones Verchere', 1, 'C/S', Decimal('1197.0000')),
#  ('Berlach, Israel & Liberman', 1, 'PA', Decimal('1880.0000')),
#  ('Blake, Cassels & Grayson', 1, 'C/S', Decimal('1600.0000')),
#  ('Blass & Driggs', 1, 'C/S', Decimal('1250.0000')),
#  ('Bobby Blake and Associates', 1, 'SS', Decimal('1100.0000')),
#  ('Boles & Boles', 1, 'C/S', Decimal('2223.0000')),
#  ('Boxenbaum, Grates', 1, 'C/S', Decimal('1617.0000')),
#  ('Bracewell & Paterson', 2, 'C/S', Decimal('2140.0000')),
#  ('Brainerd Communicators', 1, 'SS', Decimal('1600.0000')),
#  ('Broadgate Consultants', 1, 'C/S', Decimal('2820.0000')),
#  ('Brobeck, Phleger & Harrison', 2, 'TO', Decimal('2860.0000')),
#  ('Brown & Wood', 1, 'SS', Decimal('7000.0000')),
#  ('Bryan Cave', 4, 'C/S', Decimal('80080.0000')),
#  ('Bryan Cave', 2, 'SS', Decimal('4400.0000')),
#  ('BT Alex. Brown', 1, 'C/S', Decimal('1283.0000')),
#  ('BT Alex. Brown', 2, 'SS', Decimal('9930.0000')),
#  ('BT Wolfensohn', 2, 'C/S', Decimal('4300.0000')),
#  ('BT Wolfensohn', 3, 'SS', Decimal('5200.0000')),
#  ('Buchanan Ingersol', 1, 'TO', Decimal('1000.0000')),
#  ('Burson-Marsteller', 3, 'C/S', Decimal('78880.0000')),
#  ('Burson-Marsteller', 2, 'PF', Decimal('19500.0000')),
#  ('Burson-Marsteller', 3, 'SS', Decimal('11500.0000')),
#  ('Burson-Marsteller', 3, 'TO', Decimal('25700.0000')),
#  ('Cahill Gordon & Reindel', 2, 'C/S', Decimal('2947.0000')),
#  ('Cahill Gordon & Reindel', 1, 'SS', Decimal('3000.0000')),
#  ('Cahill Gordon & Reindel', 1, 'TO', Decimal('2800.0000')),
#  ('Carrerre & Denegre', 1, 'C/S', Decimal('2223.0000')),
#  ('Cazenove', 2, 'C/S', Decimal('4110.0000')),
#  ('Chadbourne & Parke', 1, 'C/S', Decimal('2223.0000')),
#  ('Chadbourne & Parke', 1, 'CM', Decimal('1500.0000')),
#  ('Chadbourne & Parke', 1, 'PF', Decimal('1700.0000')),
#  ('Chadbourne & Parke', 2, 'SS', Decimal('6600.0000')),
#  ('Chadbourne & Parke', 2, 'TO', Decimal('2970.0000')),
#  ('Chase Securities Inc.', 1, 'C/S', Decimal('2600.0000')),
#  ('Chase Securities Inc.', 2, 'SS', Decimal('6600.0000')),
#  ('Chase Securities Inc.', 2, 'TO', Decimal('6870.0000')),
#  ('CIBC Wood Gundy Inc.', 2, 'C/S', Decimal('2600.0000')),
#  ('CIBC Wood Gundy Securities, Inc.', 1, 'C/S', Decimal('1617.0000')),
#  ('Citigate Inc.', 1, 'TO', Decimal('1590.0000')),
#  ('Clark & Weinstock', 2, 'C/S', Decimal('3900.0000')),
#  ('Cleary, Gottlieb, Steen & Hamilton', 7, 'C/S', Decimal('12487.0000')),
#  ('Cleary, Gottlieb, Steen & Hamilton', 8, 'SS', Decimal('34200.0000')),
#  ('Cleary, Gottlieb, Steen & Hamilton', 2, 'TO', Decimal('2392.0000')),
#  ('Cohane Rafferty Securities Inc.', 1, 'CM', Decimal('1230.0000')),
#  ('Cooley Godward', 1, 'SS', Decimal('1180.0000')),
#  ('Copithorne & Bellows', 1, 'SS', Decimal('1180.0000')),
#  ('Corporate Communications', 1, 'SS', Decimal('2900.0000')),
#  ('Corporate Investor Communications Inc.', 2, 'C/S', Decimal('8160.0000')),
#  ('Corporate Investor Communications Inc.', 6, 'SS', Decimal('11400.0000')),
#  ('Correro Fishman Haygood Phelps Weiss Walmsey & Cas', 1, 'SS', Decimal('3000.0000')),
#  ('Cravath, Swaine & Moore', 17, 'C/S', Decimal('192635.0000')),
#  ('Cravath, Swaine & Moore', 2, 'PF', Decimal('19500.0000')),
#  ('Cravath, Swaine & Moore', 10, 'SS', Decimal('44759.0000')),
#  ('Cravath, Swaine & Moore', 5, 'TO', Decimal('28700.0000')),
#  ('Credit Suisse First Boston', 12, 'C/S', Decimal('42752.0000')),
#  ('Credit Suisse First Boston', 1, 'PA', Decimal('1880.0000')),
#  ('Credit Suisse First Boston', 1, 'PF', Decimal('6590.0000')),
#  ('Credit Suisse First Boston', 12, 'SS', Decimal('50440.0000')),
#  ('Credit Suisse First Boston', 5, 'TO', Decimal('11590.0000')),
#  ('Crouch & Hallett', 1, 'C/S', Decimal('1355.0000')),
#  ('D.F. King & Co., Inc.', 10, 'C/S', Decimal('88518.0000')),
#  ('D.F. King & Co., Inc.', 3, 'PF', Decimal('26090.0000')),
#  ('D.F. King & Co., Inc.', 10, 'SS', Decimal('43177.0000')),
#  ('D.F. King & Co., Inc.', 6, 'TO', Decimal('38292.0000')),
#  ('Daniels & Associates', 1, 'C/S', Decimal('1150.0000')),
#  ('Davies, Ward & Beck', 1, 'SS', Decimal('1000.0000')),
#  ('Davis Polk & Wardell', 15, 'C/S', Decimal('34095.0000')),
#  ('Davis Polk & Wardell', 1, 'CM', Decimal('5300.0000')),
#  ('Davis Polk & Wardell', 9, 'SS', Decimal('35537.0000')),
#  ('Davis Polk & Wardell', 3, 'TO', Decimal('13192.0000')),
#  ('Davis Wallis Foyster', 1, 'C/S', Decimal('1330.0000')),
#  ('Debevoise & Plimpton', 7, 'C/S', Decimal('12500.0000')),
#  ('Debevoise & Plimpton', 4, 'SS', Decimal('8930.0000')),
#  ('Debevoise & Plimpton', 1, 'TO', Decimal('1800.0000')),
#  ('Dechert Price & Rhoads', 3, 'C/S', Decimal('78880.0000')),
#  ('Dechert Price & Rhoads', 1, 'SS', Decimal('2322.0000')),
#  ('Deutsche Morgan Grenfell', 1, 'C/S', Decimal('1810.0000')),
#  ('Deutsche Morgan Grenfell', 2, 'SS', Decimal('4880.0000')),
#  ('Deutsche Morgan Grenfell', 1, 'TO', Decimal('1800.0000')),
#  ('Dewe Rogerson, Inc.', 1, 'SS', Decimal('1500.0000')),
#  ('Dewey Ballantine', 16, 'C/S', Decimal('128640.0000')),
#  ('Dewey Ballantine', 1, 'CM', Decimal('1230.0000')),
#  ('Dewey Ballantine', 1, 'PA', Decimal('1880.0000')),
#  ('Dewey Ballantine', 5, 'PF', Decimal('45590.0000')),
#  ('Dewey Ballantine', 14, 'SS', Decimal('57489.0000')),
#  ('Dewey Ballantine', 9, 'TO', Decimal('50662.0000')),
#  ('Dewey Square', 2, 'PF', Decimal('19500.0000')),
#  ('Dewey Square', 2, 'TO', Decimal('19500.0000')),
#  ('Dickstein Shapiro Morin & Oshinsky', 1, 'TO', Decimal('1000.0000')),
#  ('Dillon, Read & Co. Inc.', 2, 'C/S', Decimal('2910.0000')),
#  ('Dillon, Read & Co. Inc.', 1, 'SS', Decimal('3000.0000')),
#  ('Dinsmore & Shohl', 1, 'C/S', Decimal('2000.0000')),
#  ('Donaldson, Lufkin & Jenrette Securities Corp.', 5, 'C/S', Decimal('6485.0000')),
#  ('Donaldson, Lufkin & Jenrette Securities Corp.', 1, 'CM', Decimal('1500.0000')),
#  ('Donaldson, Lufkin & Jenrette Securities Corp.', 2, 'PF', Decimal('19500.0000')),
#  ('Donaldson, Lufkin & Jenrette Securities Corp.', 5, 'SS', Decimal('14300.0000')),
#  ('Donaldson, Lufkin & Jenrette Securities Corp.', 2, 'TO', Decimal('19500.0000')),
#  ('Dorsey & Whitney', 1, 'SS', Decimal('9000.0000')),
#  ('Dresdner Kleinwort Benson', 1, 'C/S', Decimal('1870.0000')),
#  ('Drinker Biddle & Reath', 1, 'SS', Decimal('1180.0000')),
#  ('Duane, Morris & Heckscher', 1, 'SS', Decimal('1100.0000')),
#  ('Edelman Public Relations World', 1, 'C/S', Decimal('1283.0000')),
#  ('Edelman Public Relations World', 1, 'SS', Decimal('1100.0000')),
#  ('Evercore Group Inc.', 1, 'TO', Decimal('6200.0000')),
#  ('Evercore Partners', 1, 'C/S', Decimal('2560.0000')),
#  ('Faegre & Benson', 1, 'C/S', Decimal('1490.0000')),
#  ('Financial Dynamics', 1, 'C/S', Decimal('1810.0000')),
#  ('Financial Dynamics', 1, 'TO', Decimal('2800.0000')),
#  ('Fleishman-Hillard, Inc.', 1, 'SS', Decimal('5600.0000')),
#  ('Fleishman-Hillard, Inc.', 1, 'TO', Decimal('5600.0000')),
#  ('Foster Pepper & Shefelman', 1, 'PF', Decimal('6590.0000')),
#  ('Foster Pepper & Shefelman', 1, 'SS', Decimal('6590.0000')),
#  ('Freehill, Hollingdale & Page', 1, 'PA', Decimal('1880.0000')),
#  ('Freshfields', 3, 'C/S', Decimal('11630.0000')),
#  ('Freshfields', 1, 'CM', Decimal('5300.0000')),
#  ('Freshfields', 1, 'SS', Decimal('5600.0000')),
#  ('Freshfields', 1, 'TO', Decimal('5600.0000')),
#  ('Fried, Frank, Harris, Shriver & Jacobson', 12, 'C/S', Decimal('97745.0000')),
#  ('Fried, Frank, Harris, Shriver & Jacobson', 1, 'PF', Decimal('6590.0000')),
#  ('Fried, Frank, Harris, Shriver & Jacobson', 12, 'SS', Decimal('44762.0000')),
#  ('Fried, Frank, Harris, Shriver & Jacobson', 4, 'TO', Decimal('14700.0000')),
#  ('Friedman, Billings, Ramsey & Co. Inc.', 1, 'C/S', Decimal('1075.0000')),
#  ('Fulbright & Jaworski', 2, 'C/S', Decimal('2450.0000')),
#  ('Fulbright & Jaworski', 2, 'SS', Decimal('2500.0000')),
#  ('Furman Selz Inc.', 1, 'SS', Decimal('1300.0000')),
#  ('Gallagher PR', 1, 'SS', Decimal('3700.0000')),
#  ('Gardner, Carton & Douglas', 1, 'SS', Decimal('1500.0000')),
#  ('Gavin Anderson & Company', 2, 'C/S', Decimal('2550.0000')),
#  ('Gavin Anderson & Company', 1, 'PF', Decimal('6590.0000')),
#  ('Gavin Anderson & Company', 1, 'SS', Decimal('6590.0000')),
#  ('Georgeson & Company Inc.', 9, 'C/S', Decimal('103535.0000')),
#  ('Georgeson & Company Inc.', 4, 'PF', Decimal('27790.0000')),
#  ('Georgeson & Company Inc.', 13, 'SS', Decimal('76862.0000')),
#  ('Georgeson & Company Inc.', 6, 'TO', Decimal('25690.0000')),
#  ('Gibbs & Bruns', 1, 'TO', Decimal('6200.0000')),
#  ('Gibson, Dunn & Crutcher', 7, 'C/S', Decimal('14207.0000')),
#  ('Gibson, Dunn & Crutcher', 2, 'SS', Decimal('10500.0000')),
#  ('Gibson, Dunn & Crutcher', 1, 'TO', Decimal('1000.0000')),
#  ('Gleacher Natwest Inc.', 1, 'PF', Decimal('1700.0000')),
#  ('Gleacher Natwest Inc.', 2, 'SS', Decimal('3300.0000')),
#  ('Goldman Sachs International', 2, 'TO', Decimal('4720.0000')),
#  ('Goldman, Sachs & Co.', 36, 'C/S', Decimal('148974.0000')),
#  ('Goldman, Sachs & Co.', 4, 'PF', Decimal('27790.0000')),
#  ('Goldman, Sachs & Co.', 20, 'SS', Decimal('82638.0000')),
#  ('Goldman, Sachs & Co.', 6, 'TO', Decimal('26490.0000')),
#  ('Goodman and Carr', 1, 'SS', Decimal('1000.0000')),
#  ('Goodman Phillips & Vineberg', 1, 'SS', Decimal('1000.0000')),
#  ('Goodwin, Procter & Hoar', 3, 'C/S', Decimal('3740.0000')),
#  ('Goodwin, Procter & Hoar', 1, 'SS', Decimal('4000.0000')),
#  ('Gordon Altman', 1, 'C/S', Decimal('1000.0000')),
#  ('Goulston & Storrs', 1, 'C/S', Decimal('1000.0000')),
#  ('Gray Carey Ware & Friedenrich', 2, 'SS', Decimal('11000.0000')),
#  ('Greenhill & Co.', 2, 'C/S', Decimal('3900.0000')),
#  ('Greenhill & Co.', 2, 'SS', Decimal('4600.0000')),
#  ('Hambrecht & Quist', 1, 'SS', Decimal('1300.0000')),
#  ('Hanover Capital Partners Ltd.', 1, 'CM', Decimal('1230.0000')),
#  ('Haskell Slaughter & Young', 1, 'C/S', Decimal('1250.0000')),
#  ('Heller Ehrman', 1, 'C/S', Decimal('1150.0000')),
#  ('Heller Ehrman White & McAuliffe', 1, 'C/S', Decimal('1200.0000')),
#  ('Heller Ehrman White & McAuliffe', 1, 'SS', Decimal('1300.0000')),
#  ('Hogan & Hartson', 3, 'SS', Decimal('6439.0000')),
#  ('Howard & Howard', 1, 'C/S', Decimal('6800.0000')),
#  ('Huber Lawrence Abel', 1, 'TO', Decimal('1920.0000')),
#  ('Hughes Hubbard & Reed', 1, 'C/S', Decimal('12000.0000')),
#  ('Hunton & Williams', 1, 'C/S', Decimal('1080.0000')),
#  ('Hutchins, Wheeler & Ditmar', 1, 'CM', Decimal('1230.0000')),
#  ('in-house', 1, 'C/S', Decimal('1200.0000')),
#  ('in-house', 1, 'CM', Decimal('5300.0000')),
#  ('in-house', 1, 'SS', Decimal('1000.0000')),
#  ('Innisfree M&A Inc.', 3, 'C/S', Decimal('78880.0000')),
#  ('Innisfree M&A Inc.', 1, 'SS', Decimal('6600.0000')),
#  ('Innisfree M&A Inc.', 2, 'TO', Decimal('3720.0000')),
#  ('J.P. Morgan & Co., Inc.', 5, 'C/S', Decimal('24557.0000')),
#  ('J.P. Morgan & Co., Inc.', 1, 'PA', Decimal('1880.0000')),
#  ('J.P. Morgan & Co., Inc.', 4, 'SS', Decimal('24250.0000')),
#  ('J.P. Morgan & Co., Inc.', 1, 'TO', Decimal('6200.0000')),
#  ('J.P. Morgan Securities Inc.', 1, 'C/S', Decimal('1100.0000')),
#  ('Jaffoni & Collins Inc.', 1, 'SS', Decimal('1600.0000')),
#  ('Jones, Day, Reavis & Pogue', 13, 'C/S', Decimal('110945.0000')),
#  ('Jones, Day, Reavis & Pogue', 6, 'SS', Decimal('17686.0000')),
#  ('Jones, Day, Reavis & Pogue', 1, 'TO', Decimal('1700.0000')),
#  ('Jones, Walker, Wachter, Poitevent, Carrere & Denegre', 1, 'C/S', Decimal('2223.0000')),
#  ('Jose, Henry, Brantley & Keltner', 1, 'TO', Decimal('6200.0000')),
#  ('Kantrow, Spaht, Weaver & Blitzer', 1, 'TO', Decimal('6200.0000')),
#  ('Katten Muchin & Zavis', 1, 'C/S', Decimal('1120.0000')),
#  ('Katten Muchin & Zavis', 1, 'SS', Decimal('1230.0000')),
#  ('Katten Muchin & Zavis', 1, 'TO', Decimal('1800.0000')),
#  ('Keefe, Bruyette & Woods, Inc.', 1, 'CM', Decimal('1230.0000')),
#  ('Keefe, Bruyette & Woods, Inc.', 2, 'SS', Decimal('5300.0000')),
#  ('Kekst and Company', 14, 'C/S', Decimal('39970.0000')),
#  ('Kekst and Company', 1, 'CM', Decimal('1500.0000')),
#  ('Kekst and Company', 2, 'PF', Decimal('8290.0000')),
#  ('Kekst and Company', 14, 'SS', Decimal('52568.0000')),
#  ('Kekst and Company', 3, 'TO', Decimal('8520.0000')),
#  ('Ketchum Public Relations', 2, 'SS', Decimal('3000.0000')),
#  ('King & Spalding', 1, 'C/S', Decimal('1100.0000')),
#  ('Kirkland & Ellis', 4, 'C/S', Decimal('7450.0000')),
#  ('Kirkland & Ellis', 1, 'SS', Decimal('9500.0000')),
#  ('Kissel-Blake Inc.', 2, 'SS', Decimal('3200.0000')),
#  ('Kramer, Levin, Naftalis & Frankel', 1, 'C/S', Decimal('4000.0000')),
#  ('Kramer, Levin, Naftalis & Frankel', 1, 'SS', Decimal('1200.0000')),
#  ('Kramer, Levin, Naftalis, Nesse, Kamin & Frankel', 1, 'SS', Decimal('5600.0000')),
#  ('Kramer, Levin, Naftalis, Nesse, Kamin & Frankel', 1, 'TO', Decimal('5600.0000')),
#  ('Kummer Kaempfer Bonner & Renshaw', 2, 'PF', Decimal('19500.0000')),
#  ('Kummer Kaempfer Bonner & Renshaw', 2, 'TO', Decimal('19500.0000')),
#  ('Latham & Watkins', 6, 'C/S', Decimal('7983.0000')),
#  ('Latham & Watkins', 2, 'PF', Decimal('19500.0000')),
#  ('Latham & Watkins', 3, 'SS', Decimal('6700.0000')),
#  ('Latham & Watkins', 2, 'TO', Decimal('19500.0000')),
#  ('Lazard Brothers & Company Ltd.', 1, 'C/S', Decimal('9700.0000')),
#  ('Lazard Brothers & Company Ltd.', 1, 'CM', Decimal('5300.0000')),
#  ('Lazard Freres & Co. LLC', 9, 'C/S', Decimal('94160.0000')),
#  ('Lazard Freres & Co. LLC', 2, 'PF', Decimal('19500.0000')),
#  ('Lazard Freres & Co. LLC', 1, 'SS', Decimal('7000.0000')),
#  ('Lazard Freres & Co. LLC', 2, 'TO', Decimal('19500.0000')),
#  ('LeBoeuf, Lamb, Greene & MacRae', 1, 'C/S', Decimal('4210.0000')),
#  ('LeBoeuf, Lamb, Greene & MacRae', 2, 'SS', Decimal('2730.0000')),
#  ('Lehman Brothers', 8, 'C/S', Decimal('92170.0000')),
#  ('Lehman Brothers', 1, 'CM', Decimal('1500.0000')),
#  ('Lehman Brothers', 1, 'PF', Decimal('6590.0000')),
#  ('Lehman Brothers', 7, 'SS', Decimal('19690.0000')),
#  ('Lehman Brothers', 2, 'TO', Decimal('8120.0000')),
#  ('Liddell, Sapp, Zivley, Hill & LaBoon', 1, 'SS', Decimal('1200.0000')),
#  ('Liebowitz & Associates', 1, 'C/S', Decimal('1200.0000')),
#  ('Linklaters & Paines', 4, 'C/S', Decimal('88580.0000')),
#  ('Linklaters & Paines', 1, 'TO', Decimal('2800.0000')),
#  ('Locke, Purnell, Rain & Harrell', 1, 'C/S', Decimal('1100.0000')),
#  ('Long Aldridge Norman', 1, 'C/S', Decimal('1617.0000')),
#  ('Lowenstein, Sandler, Kohl, Fisher & Boy-Ian', 1, 'SS', Decimal('2500.0000')),
#  ('MacKenzie Partners, Inc.', 3, 'C/S', Decimal('5550.0000')),
#  ('MacKenzie Partners, Inc.', 1, 'CM', Decimal('1500.0000')),
#  ('MacKenzie Partners, Inc.', 3, 'PF', Decimal('26090.0000')),
#  ('MacKenzie Partners, Inc.', 3, 'SS', Decimal('21190.0000')),
#  ('MacKenzie Partners, Inc.', 4, 'TO', Decimal('26100.0000')),
#  ('Mallesons, Stephens, Jacques', 1, 'PA', Decimal('1880.0000')),
#  ('Mayer, Brown & Platt', 3, 'C/S', Decimal('4100.0000')),
#  ('Mayer, Brown & Platt', 1, 'SS', Decimal('7300.0000')),
#  ('Mayer, Brown & Platt', 1, 'TO', Decimal('1270.0000')),
#  ('Mayor, Day, Caldwell & Keeton', 1, 'SS', Decimal('1000.0000')),
#  ('McCormick & Pryor', 1, 'SS', Decimal('1180.0000')),
#  ('McDermott, Will & Emery', 1, 'C/S', Decimal('1100.0000')),
#  ('McDermott, Will & Emery', 1, 'SS', Decimal('1500.0000')),
#  ('McDonald & Co.', 1, 'SS', Decimal('1050.0000')),
#  ('McGuire, Woods, Battle & Boothe', 2, 'SS', Decimal('6650.0000')),
#  ('Merrill Lynch & Co.', 20, 'C/S', Decimal('33625.0000')),
#  ('Merrill Lynch & Co.', 2, 'CM', Decimal('2730.0000')),
#  ('Merrill Lynch & Co.', 3, 'PF', Decimal('26090.0000')),
#  ('Merrill Lynch & Co.', 25, 'SS', Decimal('104206.0000')),
#  ('Merrill Lynch & Co.', 6, 'TO', Decimal('30700.0000')),
#  ('Milbank, Tweed, Hadley & McCloy', 5, 'C/S', Decimal('89660.0000')),
#  ('Miller & Martin', 1, 'C/S', Decimal('1617.0000')),
#  ('Miller Shandwick Technologies', 1, 'SS', Decimal('3000.0000')),
#  ('Miller, Nash, Wiener, Hagen & Carlsen', 1, 'SS', Decimal('9000.0000')),
#  ('Montgomery Securities', 1, 'C/S', Decimal('1000.0000')),
#  ('Montgomery Securities', 2, 'PF', Decimal('8290.0000')),
#  ('Montgomery Securities', 3, 'SS', Decimal('23790.0000')),
#  ('Montgomery Securities', 2, 'TO', Decimal('2392.0000')),
#  ('Morgan Stanley & Co. Inc.', 12, 'C/S', Decimal('101840.0000')),
#  ('Morgan Stanley & Co. Inc.', 11, 'SS', Decimal('47980.0000')),
#  ('Morgan Stanley & Co. Inc.', 5, 'TO', Decimal('7680.0000')),
#  ('Morgan Stanley Dean Witter', 12, 'C/S', Decimal('47820.0000')),
#  ('Morgan Stanley Dean Witter', 7, 'SS', Decimal('30360.0000')),
#  ('Morgan Stanley Dean Witter', 1, 'TO', Decimal('1392.0000')),
#  ('Morgan, Lewis & Bockius', 1, 'C/S', Decimal('1200.0000')),
#  ('Morgan, Lewis & Bockius', 1, 'SS', Decimal('3100.0000')),
#  ('Morgan, Lewis & Bockius', 1, 'TO', Decimal('6200.0000')),
#  ('Morris, Nichols, Arsht & Tunnell', 11, 'C/S', Decimal('91720.0000')),
#  ('Morris, Nichols, Arsht & Tunnell', 4, 'PF', Decimal('27790.0000')),
#  ('Morris, Nichols, Arsht & Tunnell', 10, 'SS', Decimal('37720.0000')),
#  ('Morris, Nichols, Arsht & Tunnell', 2, 'TO', Decimal('19500.0000')),
#  ('Morrison & Foerster', 1, 'SS', Decimal('3000.0000')),
#  ('Morrison & Foerster', 1, 'TO', Decimal('1900.0000')),
#  ('Morrison & Hecker', 1, 'C/S', Decimal('1100.0000')),
#  ('Morrow & Co., Inc.', 1, 'C/S', Decimal('1200.0000')),
#  ('Morrow & Co., Inc.', 6, 'SS', Decimal('11087.0000')),
#  ('Morrow & Co., Inc.', 3, 'TO', Decimal('9800.0000')),
#  ('Munger, Tolles & Olson', 1, 'C/S', Decimal('1700.0000')),
#  ('Munsch Hardt Kopf Harr & Dinan', 1, 'C/S', Decimal('1080.0000')),
#  ('NationsBanc Capital Markets', 2, 'SS', Decimal('2000.0000')),
#  ('NationsBanc Capital Markets', 1, 'TO', Decimal('1000.0000')),
#  ('Nationsbank ontgomery Securities', 1, 'C/S', Decimal('6800.0000')),
#  ('Neal, Gerber & Eisenberg', 2, 'C/S', Decimal('2625.0000')),
#  ('Nesbitt Burns Inc.', 1, 'C/S', Decimal('1500.0000')),
#  ('NM Rothschild', 1, 'C/S', Decimal('2300.0000')),
#  ('NM Rothschild', 1, 'TO', Decimal('2800.0000')),
#  ('Noonan/Russo Communications, Inc.', 1, 'SS', Decimal('1650.0000')),
#  ('Nyemaster, Goode, McLaughlin, Voigts, West, Hansel', 1, 'C/S', Decimal('2600.0000')),
#  ("O'Melveny & Myers", 6, 'C/S', Decimal('82880.0000')),
#  ("O'Melveny & Myers", 1, 'TO', Decimal('1000.0000')),
#  ('Orrick, Herrington & Sutcliffe', 1, 'SS', Decimal('1500.0000')),
#  ('Orrick, Herrington & Sutcliffe', 1, 'TO', Decimal('1800.0000')),
#  ('Oscar Folger, solo practitioner', 1, 'SS', Decimal('1500.0000')),
#  ('Osler, Hoskin & Harcourt', 1, 'SS', Decimal('1000.0000')),
#  ('PaineWebber Inc.', 3, 'C/S', Decimal('3740.0000')),
#  ('PaineWebber Inc.', 1, 'SS', Decimal('1389.0000')),
#  ('Paul, Weiss, Rifkind, Wharton & Garrison', 11, 'C/S', Decimal('167835.0000')),
#  ('Paul, Weiss, Rifkind, Wharton & Garrison', 8, 'SS', Decimal('22000.0000')),
#  ('Paul, Weiss, Rifkind, Wharton & Garrison', 1, 'TO', Decimal('1392.0000')),
#  ('Peper, Martin, Jensen, Maichel and Hetlage', 1, 'SS', Decimal('2900.0000')),
#  ('Pepper, Hamilton & Scheetz', 1, 'C/S', Decimal('1360.0000')),
#  ('Perkins Coie', 1, 'C/S', Decimal('2820.0000')),
#  ('Peter J. Solomon Company', 1, 'SS', Decimal('2322.0000')),
#  ('Pillsbury Madison & Sutro', 1, 'C/S', Decimal('1490.0000')),
#  ('Pillsbury Madison & Sutro', 1, 'SS', Decimal('5000.0000')),
#  ('Piper & Marbury', 1, 'C/S', Decimal('1150.0000')),
#  ('Piper & Marbury', 1, 'SS', Decimal('1700.0000')),
#  ('Potter Anderson & Corroon', 3, 'C/S', Decimal('4200.0000')),
#  ('Powell, Goldstein, Frazer & Murphy', 1, 'C/S', Decimal('1000.0000')),
#  ('Powell, Goldstein, Frazer & Murphy', 1, 'SS', Decimal('1000.0000')),
#  ('Proskauer Rose Goetz Mendelsohn', 2, 'C/S', Decimal('2625.0000')),
#  ('Quarles & Brady', 1, 'TO', Decimal('1800.0000')),
#  ('Raymond James & Associates Inc.', 1, 'SS', Decimal('1230.0000')),
#  ('Raymond James & Associates Inc.', 1, 'TO', Decimal('1800.0000')),
#  ('RBC Dominion Securities Inc.', 2, 'C/S', Decimal('2814.0000')),
#  ('Richards, Layton & Finger', 19, 'C/S', Decimal('118730.0000')),
#  ('Richards, Layton & Finger', 1, 'CM', Decimal('1500.0000')),
#  ('Richards, Layton & Finger', 2, 'PF', Decimal('8290.0000')),
#  ('Richards, Layton & Finger', 20, 'SS', Decimal('80559.0000')),
#  ('Richards, Layton & Finger', 3, 'TO', Decimal('13700.0000')),
#  ('Riordan & McKenzie', 1, 'SS', Decimal('1100.0000')),
#  ('Robinson Lerer & Montgomery', 1, 'PF', Decimal('1700.0000')),
#  ('Robinson Lerer & Montgomery', 2, 'SS', Decimal('12600.0000')),
#  ('Robinson Lerer & Montgomery', 1, 'TO', Decimal('6200.0000')),
#  ('Robinson Silverman Pearce Aronsohn & Berman', 2, 'C/S', Decimal('3900.0000')),
#  ('Rogers & Wells', 3, 'C/S', Decimal('3905.0000')),
#  ('Rogers & Wells', 1, 'SS', Decimal('2500.0000')),
#  ('Ropes & Gray', 1, 'C/S', Decimal('1120.0000')),
#  ('Rosenberg & Liebentritt', 2, 'SS', Decimal('5700.0000')),
#  ('Rothschild Inc./NM Rothschild & Sons Ltd.', 3, 'C/S', Decimal('78880.0000')),
#  ('Rudnick & Wolfe', 1, 'C/S', Decimal('1057.0000')),
#  ('Salomon Brothers Inc.', 11, 'C/S', Decimal('97187.0000')),
#  ('Salomon Brothers Inc.', 8, 'SS', Decimal('39400.0000')),
#  ('Salomon Brothers Inc.', 2, 'TO', Decimal('6600.0000')),
#  ('Salomon Smith Barney', 2, 'SS', Decimal('10060.0000')),
#  ('Sard Verbinnen & Co., Inc.', 8, 'C/S', Decimal('87400.0000')),
#  ('Sard Verbinnen & Co., Inc.', 2, 'PF', Decimal('19500.0000')),
#  ('Sard Verbinnen & Co., Inc.', 3, 'SS', Decimal('22770.0000')),
#  ('Sard Verbinnen & Co., Inc.', 3, 'TO', Decimal('21300.0000')),
#  ('SBC Warburg', 1, 'C/S', Decimal('8000.0000')),
#  ('Schreck Morris', 2, 'PF', Decimal('19500.0000')),
#  ('Schreck Morris', 2, 'TO', Decimal('19500.0000')),
#  ('Schroder Wertheim & Co.', 1, 'TO', Decimal('1392.0000')),
#  ('Schulte Roth & Zabel', 2, 'C/S', Decimal('3900.0000')),
#  ('Shareholder Communications Corporation', 1, 'C/S', Decimal('9700.0000')),
#  ('Shearman & Sterling', 13, 'C/S', Decimal('105002.0000')),
#  ('Shearman & Sterling', 1, 'CM', Decimal('5300.0000')),
#  ('Shearman & Sterling', 1, 'PF', Decimal('1700.0000')),
#  ('Shearman & Sterling', 14, 'SS', Decimal('52519.0000')),
#  ('Shearman & Sterling', 5, 'TO', Decimal('11910.0000')),
#  ('Sheehan Phinney Bass & Green', 1, 'TO', Decimal('1700.0000')),
#  ('Sidley & Austin', 2, 'C/S', Decimal('3280.0000')),
#  ('Sidley & Austin', 2, 'PF', Decimal('19500.0000')),
#  ('Sidley & Austin', 2, 'SS', Decimal('2700.0000')),
#  ('Sidley & Austin', 2, 'TO', Decimal('19500.0000')),
#  ('Simpson Thacher & Bartlett', 15, 'C/S', Decimal('126630.0000')),
#  ('Simpson Thacher & Bartlett', 1, 'CM', Decimal('1500.0000')),
#  ('Simpson Thacher & Bartlett', 3, 'PF', Decimal('26090.0000')),
#  ('Simpson Thacher & Bartlett', 21, 'SS', Decimal('81449.0000')),
#  ('Simpson Thacher & Bartlett', 6, 'TO', Decimal('30892.0000')),
#  ('SJ Berwin & Co.', 1, 'C/S', Decimal('2000.0000')),
#  ('Skadden, Arps, Slate, Meagher & Flom', 17, 'C/S', Decimal('43180.0000')),
#  ('Skadden, Arps, Slate, Meagher & Flom', 1, 'CM', Decimal('1230.0000')),
#  ('Skadden, Arps, Slate, Meagher & Flom', 4, 'PF', Decimal('27790.0000')),
#  ('Skadden, Arps, Slate, Meagher & Flom', 21, 'SS', Decimal('80130.0000')),
#  ('Skadden, Arps, Slate, Meagher & Flom', 8, 'TO', Decimal('35190.0000')),
#  ('Skinner & Co.', 2, 'SS', Decimal('5000.0000')),
#  ('Slaughter & May', 3, 'C/S', Decimal('19510.0000')),
#  ('Smith Barney Inc.', 6, 'C/S', Decimal('9590.0000')),
#  ('Smith Barney Inc.', 1, 'CM', Decimal('1230.0000')),
#  ('Smith Barney Inc.', 6, 'SS', Decimal('15919.0000')),
#  ('Smith Barney Inc.', 2, 'TO', Decimal('7592.0000')),
#  ('Societe Generale Securities Corporation', 1, 'C/S', Decimal('2000.0000')),
#  ('Sonnenschein Nath & Rosenthal', 1, 'TO', Decimal('1800.0000')),
#  ('Squardon, Ellenoff', 1, 'C/S', Decimal('1900.0000')),
#  ('Squardon, Ellenoff, Plesent & Sheinfeld', 1, 'C/S', Decimal('1355.0000')),
#  ('Stikeman, Elliot', 2, 'C/S', Decimal('3117.0000')),
#  ('Stoel Rives', 2, 'C/S', Decimal('11923.0000')),
#  ('Stoel Rives', 2, 'SS', Decimal('4800.0000')),
#  ('Stroock & Stroock & Lavan', 1, 'C/S', Decimal('1000.0000')),
#  ('Stroock & Stroock & Lavan', 1, 'TO', Decimal('1000.0000')),
#  ('Sullivan & Cromwell', 33, 'C/S', Decimal('151054.0000')),
#  ('Sullivan & Cromwell', 1, 'CM', Decimal('1230.0000')),
#  ('Sullivan & Cromwell', 1, 'PF', Decimal('6590.0000')),
#  ('Sullivan & Cromwell', 18, 'SS', Decimal('73266.0000')),
#  ('Sullivan & Cromwell', 6, 'TO', Decimal('14390.0000')),
#  ('Sullivan & Worcester', 1, 'C/S', Decimal('2600.0000')),
#  ('Sutherland, Asbill & Brennan', 2, 'C/S', Decimal('4220.0000')),
#  ('Swindler & Berlin', 4, 'C/S', Decimal('79960.0000')),
#  ('Taft, Stettinius & Hollister', 1, 'C/S', Decimal('1100.0000')),
#  ('Tanner & Co. Inc.', 2, 'C/S', Decimal('3000.0000')),
#  ('The Abernathy / MacGregor Group, Inc.', 10, 'C/S', Decimal('98040.0000')),
#  ('The Abernathy / MacGregor Group, Inc.', 1, 'CM', Decimal('1230.0000')),
#  ('The Abernathy / MacGregor Group, Inc.', 3, 'PF', Decimal('26090.0000')),
#  ('The Abernathy / MacGregor Group, Inc.', 11, 'SS', Decimal('76527.0000')),
#  ('The Abernathy / MacGregor Group, Inc.', 4, 'TO', Decimal('27020.0000')),
#  ('The Atkins Company', 1, 'SS', Decimal('1500.0000')),
#  ('The Blackstone Group L.P.', 2, 'C/S', Decimal('2640.0000')),
#  ('The Blackstone Group L.P.', 1, 'SS', Decimal('1500.0000')),
#  ('The Dilenschneider Group', 1, 'C/S', Decimal('2000.0000')),
#  ('Thompson, Hine & Flory', 1, 'C/S', Decimal('1000.0000')),
#  ('Tillinghast', 1, 'C/S', Decimal('2600.0000')),
#  ('Toronto Dominion', 1, 'C/S', Decimal('1600.0000')),
#  ('Tory, Tory, DesLauriers & Binnington', 2, 'C/S', Decimal('3117.0000')),
#  ('Troop, Meisinger, Steuer, Pasich', 1, 'C/S', Decimal('1900.0000')),
#  ('Troutman Sanders', 1, 'C/S', Decimal('1870.0000')),
#  ('UBS Securities', 2, 'C/S', Decimal('8083.0000')),
#  ('UBS Securities', 3, 'SS', Decimal('9700.0000')),
#  ('UBS Securities', 1, 'TO', Decimal('1590.0000')),
#  ('Union Bank of Switzerland', 1, 'C/S', Decimal('1617.0000')),
#  ('Venture Law Group', 1, 'SS', Decimal('1100.0000')),
#  ('Vinson & Elkins', 2, 'C/S', Decimal('2397.0000')),
#  ('Vinson & Elkins', 3, 'SS', Decimal('10050.0000')),
#  ('Vinson & Elkins', 1, 'TO', Decimal('1270.0000')),
#  ('Wachtell, Lipton, Rosen & Katz', 13, 'C/S', Decimal('28480.0000')),
#  ('Wachtell, Lipton, Rosen & Katz', 2, 'PF', Decimal('19500.0000')),
#  ('Wachtell, Lipton, Rosen & Katz', 16, 'SS', Decimal('78939.0000')),
#  ('Wachtell, Lipton, Rosen & Katz', 2, 'TO', Decimal('19500.0000')),
#  ('Waller Lansden Dortch & Davis', 1, 'SS', Decimal('8180.0000')),
#  ('Wasserstein Perella & Co. Inc.', 4, 'C/S', Decimal('5975.0000')),
#  ('Wasserstein Perella & Co. Inc.', 4, 'SS', Decimal('17189.0000')),
#  ('Watson Farley', 2, 'C/S', Decimal('2625.0000')),
#  ('Weil, Gotshal & Manges', 8, 'C/S', Decimal('32388.0000')),
#  ('Weil, Gotshal & Manges', 4, 'SS', Decimal('17100.0000')),
#  ('White & Case', 2, 'C/S', Decimal('4550.0000')),
#  ('White & Case', 2, 'SS', Decimal('12500.0000')),
#  ('White & Case', 2, 'TO', Decimal('3820.0000')),
#  ('Wilcox & Savage', 1, 'C/S', Decimal('1080.0000')),
#  ('Wiley, Rein & Fielding', 3, 'C/S', Decimal('5100.0000')),
#  ('William Blair & Company', 1, 'TO', Decimal('1800.0000')),
#  ('Williams, Mullen, Christian & Dobbins', 1, 'SS', Decimal('2300.0000')),
#  ('Willkie Farr & Gallagher', 6, 'C/S', Decimal('9767.0000')),
#  ('Willkie Farr & Gallagher', 3, 'SS', Decimal('10622.0000')),
#  ('Willkie Farr & Gallagher', 1, 'TO', Decimal('1920.0000')),
#  ('Wilmer, Cutler & Pickering', 2, 'C/S', Decimal('13100.0000')),
#  ('Wilmer, Cutler & Pickering', 1, 'SS', Decimal('3000.0000')),
#  ('Wilson, Sonsini, Goodrich & Rosati', 1, 'PF', Decimal('1700.0000')),
#  ('Wilson, Sonsini, Goodrich & Rosati', 4, 'SS', Decimal('5480.0000')),
#  ('Wilson, Sonsini, Goodrich & Rosati', 1, 'TO', Decimal('1800.0000')),
#  ('Winthrop, Stimson, Putnam & Roberts', 1, 'C/S', Decimal('2100.0000')),
#  ('Winthrop, Stimson, Putnam & Roberts', 1, 'CM', Decimal('1500.0000')),
#  ('Wolf, Block, Schorr & Cohe', 1, 'C/S', Decimal('1300.0000')),
#  ('Wolfensohn', 1, 'C/S', Decimal('1283.0000')),
#  ('Young, Conaway, Stargatt & Taylor', 1, 'C/S', Decimal('1700.0000'))]

# %%
### Query 5: Make up your own query to share.
Be creative. Impress us with your brilliance!

# %% [markdown]
# Sean Bernard
